# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_dataset.csv")
df.head()
# Out:
#          Date   Product  Sales
# 0  2025-01-05    Laptop  75000
# 1  2025-01-10     Mouse   1500
# 2  2025-01-15  Keyboard   3000
# 3  2025-02-01    Laptop  82000
# 4  2025-02-18     Mouse   1700

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     7 non-null      object
#  1   Product  7 non-null      object
#  2   Sales    7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes
#               Sales
# count      7.000000
# mean   36671.428571
# std    42937.618094
# min     1500.000000
# 25%     2350.000000
# 50%     3500.000000
# 75%    78500.000000
# max    90000.000000

# %%
product_sales = df.groupby("Product")["Sales"].sum()
print(product_sales)
# Out:
# Product
# Keyboard      6500
# Laptop      247000
# Mouse         3200
# Name: Sales, dtype: int64

# %%
product_sales.plot(kind="bar")
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Month"] = df["Date"].dt.month

month_sales = df.groupby("Month")["Sales"].sum()
month_sales
# Out:
# Month
# 1    79500
# 2    83700
# 3    93500
# Name: Sales, dtype: int64

# %%
month_sales.plot(kind="line", marker="o")
plt.title("Sales Trend by Month")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()
